# %% [markdown]
# # Data Merge

# %%
import pandas as pd
import matplotlib.pyplot as plt
import missingno as msno
import datetime as dt
import numpy as np

cotton1=pd.read_csv(r'C:\Users\fatem\OneDrive - Virginia Tech\Desktop\readings\Gardencity\Cotton 10 min season 1 and 2_raw_rh.csv',parse_dates=['Time'],na_values=['NAN'])
east_summer=pd.read_csv(r'C:\Users\fatem\OneDrive - Virginia Tech\Desktop\readings\Gardencity\7_21_2021_6_03_2022east.csv',parse_dates=['Time'],low_memory=False)
west_gs1=pd.read_csv(r'C:\Users\fatem\OneDrive - Virginia Tech\Desktop\readings\Gardencity\7_21_2021_6_3_2022_west.csv',parse_dates=['Time'],low_memory=False)
missing=pd.read_csv(r'C:\Users\fatem\OneDrive - Virginia Tech\Desktop\readings\Gardencity\missing_dates.csv',parse_dates=['Time'],low_memory=False)
cotton4=pd.read_csv(r'C:\Users\fatem\OneDrive - Virginia Tech\Desktop\readings\Gardencity\6_8_2022_11_10_2022_west.csv',parse_dates=['Time'],na_values=['NAN'])

mask=(east_summer['Time'] >= '4/20/2022') & (east_summer['Time'] <= '4/30/2022')
cotton2=east_summer.loc[mask]

mask2=(west_gs1['Time'] >= '5/1/2022') & (west_gs1['Time'] <= '6/3/2022')
cotton3=west_gs1.loc[mask2]

cotton_data1=cotton1.append(cotton2,ignore_index=False,sort=False)
cotton_data2=cotton_data1.append(cotton3,ignore_index=False,sort=False)
cotton_data3=cotton_data2.append(missing,ignore_index=False,sort=False)
cotton_data=cotton_data3.append(cotton4,ignore_index=False,sort=False)


cotton_data['Time'] = pd.to_datetime(cotton_data['Time'])
print(cotton_data['Time'].dtypes)

column_names=['Time']
#duplicates=cotton_data.duplicated(subset=column_names,keep=False)

cotton_data.sort_values('Time', inplace = True)
#dropping duplicate values
cotton_data.drop_duplicates(subset=column_names,keep='first',inplace=True)

duplicates=cotton_data.duplicated(subset=column_names,keep=False)
print(cotton_data[duplicates])
print(duplicates)
#saving new file for cotton
# cotton_data.to_csv(r'C:\Users\fatemapiu\Desktop\Gardencity\Cotton\daily\unsat\dry_mep_1141_z_5_growing season2021_unsat.csv',na_rep='NAN')
# cotton_data.to_csv(r'C:\Users\fatemapiu\Desktop\Gardencity\Corn\unsat\corn_mep_1141_z_5_growing season2021_unsat.csv',na_rep='NAN')
# cotton_data.to_csv('Cotton daily_1_2_with_adj.csv',na_rep='NAN')
# cotton_data.to_csv('Cotton_10_min_Season_1_and_2_raw.csv',na_rep='NAN')
# cotton_data.to_csv('East dry 10min_2021.csv', na_rep='NAN')
# print(cotton_data['Time'].tail(5))
cotton_data.to_csv(r'C:\Users\fatem\OneDrive - Virginia Tech\Desktop\readings\Gardencity\Cotton 10 min season 1 to 3_raw.csv', na_rep='NAN')
# Out:
# datetime64[ns]
# Empty DataFrame
# Columns: [Unnamed: 0, Unnamed: 0.1, Time, Time11, BattV_Min, PTemp_C_Avg, SHF_1_Avg, SHF_2_Avg, SHF_3_Avg, AirTC_Avg, AirRH_Max, AirTC_2_Avg, AirRH_2_Max, WS_ms_Avg, DetectorTC_Avg, TargetTC_Avg, Rain_mm_Tot, SWin_Avg, SWout_Avg, LWin_Avg, LWout_Avg, SWnet_Avg, LWnet_Avg, SWalbedo_Avg, NR_Avg, VWC_1_Avg, T_1_Avg, VWC_2_Avg, T_2_Avg, VWC_3_Avg, T_3_Avg, VWC_4_Avg, T_4_Avg, VWC_5_Avg, T_5_Avg, T109_C_Avg, SR01Up_Avg, SR01Dn_Avg, IR01Up_Avg, IR01Dn_Avg, NR01TC_Avg, NetRs_Avg, NetRl_Avg, Albedo_Avg, NetTot_Avg, IR01UpCo_Avg, IR01DnCo_Avg, TLWin_Avg, TLWout_Avg, VWC_6_Avg, T_6_Avg, VWC_7_Avg, T_7_Avg, RECORD, SBT_C_Avg, AirTC_1_Avg, AirRH_1_Max, T109_C_1_Avg, T107_C_2_Avg]
# Index: []
#
# [0 rows x 59 columns]
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 22314    False
# 22315    False
# 22316    False
# 22317    False
# 22318    False
# Length: 125365, dtype: bool

# %% [markdown]
# # Time Series Data Creation

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import datetime
from calendar import monthrange
from scipy import stats
# from UliEngineering.Utils.Date import *

date =datetime.datetime(2022,6,3,22,10,00)
end = datetime.datetime(2022,6,8,11,50, 00)
step = datetime.timedelta(minutes=10)

result = []
result2=[]

while date < end:
    time=date.strftime('%m-%d-%Y %H:%M:%S')
#     time1=date.strftime('%m-%d-%Y')
    result.append(time)
#     result2.append(time1)
    date += step


date = pd.DataFrame ( {'Time': result,'Time11':result})

date.to_csv(r'C:\Users\fatem\OneDrive - Virginia Tech\Desktop\readings\Gardencity\missing_dates.csv', na_rep='NAN')

# %% [markdown]
# # Data Append

# %%
import pandas as pd
import matplotlib.pyplot as plt
import missingno as msno
import datetime as dt
import numpy as np

#Appending data for cottonCotton Clean 10 min Growing Season 2020_2021_adj.csv,Cotton Clean 10 min Growing Season 2021_22_adj.csv


# cotton_1=pd.read_csv('Cotton_6_16_7_30.csv',parse_dates=['Time'],na_values=['NAN'])
# cotton_2=pd.read_csv('cotton 10 min season 1 raw.csv',parse_dates=['Time'],na_values=['NAN'])
# cotton_3=pd.read_csv('cotton_21_raw_10min_may28.csv',parse_dates=['Time'],na_values=['NAN'])
# cotton_4=pd.read_csv('cotton 10 min raw june july 2021.csv',parse_dates=['Time'],na_values=['NAN'])
# #cotton_1=pd.read_csv('Cotton_10_min_Season_1_and_2_raw.csv',parse_dates=['Time'],na_values=['NAN'])
# cotton_5=pd.read_csv('cotton 10 min raw july 13_20_2021.csv',parse_dates=['Time'],na_values=['NAN'])
# cotton_6=pd.read_csv('cotton 10 min raw july 20_25_2021.csv',parse_dates=['Time'],na_values=['NAN'])
# cotton_7=pd.read_csv('Cotton 10 minutes raw july 21to oct  13 2021.csv',parse_dates=['Time'],na_values=['NAN'])
# cotton_8=pd.read_csv('cotton 10 min oct 10 to nov 17_2021_raw.csv',parse_dates=['Time'],na_values=['NAN'])

# cotton_1=pd.read_csv(r'C:\Users\fatemapiu\Desktop\Gardencity\Cotton\daily\unsat\dry_mep_1141_z_5_june2021_unsat.csv',parse_dates=['Time'],na_values=['NAN'])
# cotton_2=pd.read_csv(r'C:\Users\fatemapiu\Desktop\Gardencity\Cotton\daily\unsat\dry_mep_1141_z_5_july2021_unsat.csv',parse_dates=['Time'],na_values=['NAN'])
# cotton_3=pd.read_csv(r'C:\Users\fatemapiu\Desktop\Gardencity\Cotton\daily\unsat\dry_mep_1141_z_5_august2021_unsat.csv',parse_dates=['Time'],na_values=['NAN'])
# cotton_4=pd.read_csv(r'C:\Users\fatemapiu\Desktop\Gardencity\Cotton\daily\unsat\dry_mep_1141_z_5_september2021_unsat.csv',parse_dates=['Time'],na_values=['NAN'])
# cotton_5=pd.read_csv(r'C:\Users\fatemapiu\Desktop\Gardencity\Cotton\daily\unsat\dry_mep_1141_z_5_october2021_unsat.csv',parse_dates=['Time'],na_values=['NAN'])
# cotton_6=pd.read_csv(r'C:\Users\fatemapiu\Desktop\Gardencity\Cotton\daily\unsat\dry_mep_1141_z_5_november2021_unsat.csv',parse_dates=['Time'],na_values=['NAN'])
# cotton_1=pd.read_csv(r'C:\Users\fatemapiu\Desktop\Gardencity\Corn\unsat\corn_mep_1141_z_5_may2021_unsat.csv',parse_dates=['Time'],na_values=['NAN'])
# cotton_2=pd.read_csv(r'C:\Users\fatemapiu\Desktop\Gardencity\Corn\unsat\corn_mep_1141_z_5_june2021_unsat.csv',parse_dates=['Time'],na_values=['NAN'])
# cotton_3=pd.read_csv(r'C:\Users\fatemapiu\Desktop\Gardencity\Corn\unsat\corn_mep_1141_z_5_july2021_unsat.csv',parse_dates=['Time'],na_values=['NAN'])
# cotton_4=pd.read_csv(r'C:\Users\fatemapiu\Desktop\Gardencity\Corn\unsat\corn_mep_1141_z_5_august2021_unsat.csv',parse_dates=['Time'],na_values=['NAN'])
# cotton_5=pd.read_csv(r'C:\Users\fatemapiu\Desktop\Gardencity\Corn\unsat\corn_mep_1141_z_5_september2021_unsat.csv',parse_dates=['Time'],na_values=['NAN'])
# cotton_6=pd.read_csv(r'C:\Users\fatemapiu\Desktop\Gardencity\Corn\unsat\corn_mep_1141_z_5_october2021_unsat.csv',parse_dates=['Time'],na_values=['NAN'])



# cotton_4=pd.read_csv(r'C:\Users\fatemapiu\Desktop\Gardencity\Cotton\daily\unsat\Cotton_mep_1141_z_5_august2021_unsat.csv',parse_dates=['Time'],na_values=['NAN'])
# cotton_5=pd.read_csv(r'C:\Users\fatemapiu\Desktop\Gardencity\Cotton\daily\unsat\Cotton_mep_1141_z_5_semptember2021_unsat.csv',parse_dates=['Time'],na_values=['NAN'])
# cotton_6=pd.read_csv(r'C:\Users\fatemapiu\Desktop\Gardencity\Cotton\daily\unsat\Cotton_mep_1141_z_5_october2021_unsat.csv',parse_dates=['Time'],na_values=['NAN'])
# cotton_7=pd.read_csv(r'C:\Users\fatemapiu\Desktop\Gardencity\Cotton\daily\unsat\Cotton_mep_1141_z_5_november2021_unsat.csv',parse_dates=['Time'],na_values=['NAN'])
# cotton_1=pd.read_csv('East Dry 10 min.csv',parse_dates=['Time'],na_values=['NAN'])
# cotton_2=pd.read_csv('east_dry_10min_july to december2021.csv',parse_dates=['Time'],na_values=['NAN'])
# cotton_1=pd.read_csv('Cotton_10_min_Season_1_and_2_raw.csv',parse_dates=['Time'],na_values=['NAN'])
# cotton_2=pd.read_csv('cotton_10min_dec_apr22.csv',parse_dates=['Time'],na_values=['NAN'])

cotton_1=pd.read_csv('Cotton 10 min season 1 and 2_raw_rh.csv',parse_dates=['Time'],na_values=['NAN'])
cotton_2=pd.read_csv('cotton_10min_dec_apr22.csv',parse_dates=['Time'],na_values=['NAN'])



# cotton_data1=cotton_1.append(cotton_2,ignore_index=False,sort=False)
# cotton_data2=cotton_data1.append(cotton_3,ignore_index=False,sort=False)
# cotton_data3=cotton_data2.append(cotton_4,ignore_index=False,sort=False)
# cotton_data4=cotton_data3.append(cotton_5,ignore_index=False,sort=False)
# cotton_data=cotton_data4.append(cotton_6,ignore_index=False,sort=False)
# cotton_data=cotton_data5.append(cotton_7,ignore_index=False,sort=False)
# cotton_data=cotton_data6.append(cotton_8,ignore_index=False,sort=False)
cotton_data=cotton_1.append(cotton_2,ignore_index=False,sort=False)
# cotton_data2=cotton_data1.append(cotton_3,ignore_index=False,sort=False)

cotton_data['Time'] = pd.to_datetime(cotton_data['Time'])
print(cotton_data['Time'].dtypes)

column_names=['Time']
#duplicates=cotton_data.duplicated(subset=column_names,keep=False)

cotton_data.sort_values('Time', inplace = True)
#dropping duplicate values
cotton_data.drop_duplicates(subset=column_names,keep='first',inplace=True)

duplicates=cotton_data.duplicated(subset=column_names,keep=False)
print(cotton_data[duplicates])
print(duplicates)
#saving new file for cotton
# cotton_data.to_csv(r'C:\Users\fatemapiu\Desktop\Gardencity\Cotton\daily\unsat\dry_mep_1141_z_5_growing season2021_unsat.csv',na_rep='NAN')
# cotton_data.to_csv(r'C:\Users\fatemapiu\Desktop\Gardencity\Corn\unsat\corn_mep_1141_z_5_growing season2021_unsat.csv',na_rep='NAN')
# cotton_data.to_csv('Cotton daily_1_2_with_adj.csv',na_rep='NAN')
# cotton_data.to_csv('Cotton_10_min_Season_1_and_2_raw.csv',na_rep='NAN')
# cotton_data.to_csv('East dry 10min_2021.csv', na_rep='NAN')
cotton_data.to_csv('Cotton 10 min season 1 and 2_raw.csv', na_rep='NAN')
# Out:
# datetime64[ns]
# Empty DataFrame
# Columns: [Unnamed: 0, Time, Time11, BattV_Min, PTemp_C_Avg, SHF_1_Avg, SHF_2_Avg, SHF_3_Avg, AirTC_Avg, RH_Max, AirTC_2_Avg, RH_2_Max, WS_ms_Avg, DetectorTC_Avg, TargetTC_Avg, Rain_mm_Tot, SWin_Avg, SWout_Avg, LWin_Avg, LWout_Avg, SWnet_Avg, LWnet_Avg, SWalbedo_Avg, NR_Avg, VWC_1_Avg, T_1_Avg, VWC_2_Avg, T_2_Avg, VWC_3_Avg, T_3_Avg, VWC_4_Avg, T_4_Avg, VWC_5_Avg, T_5_Avg, T109_C_Avg, SR01Up_Avg, SR01Dn_Avg, IR01Up_Avg, IR01Dn_Avg, NR01TC_Avg, NetRs_Avg, NetRl_Avg, Albedo_Avg, NetTot_Avg, IR01UpCo_Avg, IR01DnCo_Avg, TLWin_Avg, TLWout_Avg, VWC_6_Avg, T_6_Avg, VWC_7_Avg, T_7_Avg, RECORD]
# Index: []
#
# [0 rows x 53 columns]
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 39553    False
# 39554    False
# 39555    False
# 39556    False
# 39557    False
# Length: 96796, dtype: bool

# %%
import pandas as pd
import matplotlib.pyplot as plt
# import missingno as msno
import datetime as dt
import numpy as np

#Appending data for corn
corn_1=pd.read_csv('Corn 10 min raw season 1 and 2.csv',parse_dates=['Time','Time11'],na_values=['NAN'])
corn_2=pd.read_csv('corn_10min_dec_apr22.csv',parse_dates=['Time','Time11'],na_values=['NAN'])
# cotton_3=pd.read_csv('cotton_21_raw_10min_may28.csv',parse_dates=['Time'],na_values=['NAN'])
# cotton_4=pd.read_csv('cotton 10 min raw june july 2021.csv',parse_dates=['Time'],na_values=['NAN'])
# #cotton_1=pd.read_csv('Cotton_10_min_Season_1_and_2_raw.csv',parse_dates=['Time'],na_values=['NAN'])
# cotton_5=pd.read_csv('cotton 10 min raw july 13_20_2021.csv',parse_dates=['Time'],na_values=['NAN'])
# cotton_6=pd.read_csv('cotton 10 min raw july 20_25_2021.csv',parse_dates=['Time'],na_values=['NAN'])
# cotton_7=pd.read_csv('Cotton 10 minutes raw july 21to oct  13 2021.csv',parse_dates=['Time'],na_values=['NAN'])
# cotton_8=pd.read_csv('cotton 10 min oct 10 to nov 17_2021_raw.csv',parse_dates=['Time'],na_values=['NAN'])

# cotton_1=pd.read_csv(r'C:\Users\fatemapiu\Desktop\Gardencity\Cotton\daily\unsat\dry_mep_1141_z_5_june2021_unsat.csv',parse_dates=['Time'],na_values=['NAN'])
# cotton_2=pd.read_csv(r'C:\Users\fatemapiu\Desktop\Gardencity\Cotton\daily\unsat\dry_mep_1141_z_5_july2021_unsat.csv',parse_dates=['Time'],na_values=['NAN'])
# cotton_3=pd.read_csv(r'C:\Users\fatemapiu\Desktop\Gardencity\Cotton\daily\unsat\dry_mep_1141_z_5_august2021_unsat.csv',parse_dates=['Time'],na_values=['NAN'])
# cotton_4=pd.read_csv(r'C:\Users\fatemapiu\Desktop\Gardencity\Cotton\daily\unsat\dry_mep_1141_z_5_september2021_unsat.csv',parse_dates=['Time'],na_values=['NAN'])
# cotton_5=pd.read_csv(r'C:\Users\fatemapiu\Desktop\Gardencity\Cotton\daily\unsat\dry_mep_1141_z_5_october2021_unsat.csv',parse_dates=['Time'],na_values=['NAN'])
# cotton_6=pd.read_csv(r'C:\Users\fatemapiu\Desktop\Gardencity\Cotton\daily\unsat\dry_mep_1141_z_5_november2021_unsat.csv',parse_dates=['Time'],na_values=['NAN'])
# cotton_1=pd.read_csv(r'C:\Users\fatemapiu\Desktop\Gardencity\Corn\unsat\corn_mep_1141_z_5_may2021_unsat.csv',parse_dates=['Time'],na_values=['NAN'])
# cotton_2=pd.read_csv(r'C:\Users\fatemapiu\Desktop\Gardencity\Corn\unsat\corn_mep_1141_z_5_june2021_unsat.csv',parse_dates=['Time'],na_values=['NAN'])
# cotton_3=pd.read_csv(r'C:\Users\fatemapiu\Desktop\Gardencity\Corn\unsat\corn_mep_1141_z_5_july2021_unsat.csv',parse_dates=['Time'],na_values=['NAN'])
# cotton_4=pd.read_csv(r'C:\Users\fatemapiu\Desktop\Gardencity\Corn\unsat\corn_mep_1141_z_5_august2021_unsat.csv',parse_dates=['Time'],na_values=['NAN'])
# cotton_5=pd.read_csv(r'C:\Users\fatemapiu\Desktop\Gardencity\Corn\unsat\corn_mep_1141_z_5_september2021_unsat.csv',parse_dates=['Time'],na_values=['NAN'])
# cotton_6=pd.read_csv(r'C:\Users\fatemapiu\Desktop\Gardencity\Corn\unsat\corn_mep_1141_z_5_october2021_unsat.csv',parse_dates=['Time'],na_values=['NAN'])



# cotton_4=pd.read_csv(r'C:\Users\fatemapiu\Desktop\Gardencity\Cotton\daily\unsat\Cotton_mep_1141_z_5_august2021_unsat.csv',parse_dates=['Time'],na_values=['NAN'])
# cotton_5=pd.read_csv(r'C:\Users\fatemapiu\Desktop\Gardencity\Cotton\daily\unsat\Cotton_mep_1141_z_5_semptember2021_unsat.csv',parse_dates=['Time'],na_values=['NAN'])
# cotton_6=pd.read_csv(r'C:\Users\fatemapiu\Desktop\Gardencity\Cotton\daily\unsat\Cotton_mep_1141_z_5_october2021_unsat.csv',parse_dates=['Time'],na_values=['NAN'])
# cotton_7=pd.read_csv(r'C:\Users\fatemapiu\Desktop\Gardencity\Cotton\daily\unsat\Cotton_mep_1141_z_5_november2021_unsat.csv',parse_dates=['Time'],na_values=['NAN'])
# cotton_1=pd.read_csv('East Dry 10 min.csv',parse_dates=['Time'],na_values=['NAN'])
# cotton_2=pd.read_csv('east_dry_10min_july to december2021.csv',parse_dates=['Time'],na_values=['NAN'])
# cotton_1=pd.read_csv('Cotton daily_mean_season1.csv',parse_dates=['Time'],na_values=['NAN'])
# cotton_2=pd.read_csv('Cotton daily_mean_season2.csv',parse_dates=['Time'],na_values=['NAN'])



# cotton_data1=cotton_1.append(cotton_2,ignore_index=False,sort=False)
# cotton_data2=cotton_data1.append(cotton_3,ignore_index=False,sort=False)
# cotton_data3=cotton_data2.append(cotton_4,ignore_index=False,sort=False)
# cotton_data4=cotton_data3.append(cotton_5,ignore_index=False,sort=False)
# cotton_data=cotton_data4.append(cotton_6,ignore_index=False,sort=False)
# cotton_data=cotton_data5.append(cotton_7,ignore_index=False,sort=False)
# cotton_data=cotton_data6.append(cotton_8,ignore_index=False,sort=False)
corn_data=corn_1.append(corn_2,ignore_index=False,sort=False)
# cotton_data2=cotton_data1.append(cotton_3,ignore_index=False,sort=False)

corn_data['Time'] = pd.to_datetime(corn_data['Time'])
print(corn_data['Time'].dtypes)

column_names=['Time']
#duplicates=cotton_data.duplicated(subset=column_names,keep=False)

corn_data.sort_values('Time', inplace = True)
#dropping duplicate values
corn_data.drop_duplicates(subset=column_names,keep='first',inplace=True)

duplicates=corn_data.duplicated(subset=column_names,keep=False)
print(corn_data[duplicates])
print(duplicates)
#saving new file for corn
# cotton_data.to_csv(r'C:\Users\fatemapiu\Desktop\Gardencity\Cotton\daily\unsat\dry_mep_1141_z_5_growing season2021_unsat.csv',na_rep='NAN')
# cotton_data.to_csv(r'C:\Users\fatemapiu\Desktop\Gardencity\Corn\unsat\corn_mep_1141_z_5_growing season2021_unsat.csv',na_rep='NAN')
# cotton_data.to_csv('Cotton daily_1_2_with_adj.csv',na_rep='NAN')
# cotton_data.to_csv('Cotton_10_min_Season_1_and_2_raw.csv',na_rep='NAN')
corn_data.to_csv('Corn 10 min season 1 and 2_raw.csv', na_rep='NAN')
# Out:
# datetime64[ns]
# Empty DataFrame
# Columns: [Unnamed: 0, Time, Time11, BattV_Min, PTemp_C_Avg, SHF_1_Avg, SHF_2_Avg, SHF_3_Avg, AirTC_Avg, AirRH_Max, AirTC_2_Avg, AirRH_2_Max, TT_C_Avg, SBT_C_Avg, Rain_mm_Tot, SWin_Avg, SWout_Avg, LWin_Avg, LWout_Avg, SWnet_Avg, LWnet_Avg, SWalbedo_Avg, NR_Avg, VWC_1_Avg, T_1_Avg, VWC_2_Avg, T_2_Avg, VWC_3_Avg, T_3_Avg, VWC_4_Avg, T_4_Avg, VWC_5_Avg, T_5_Avg, T109_C_Avg, WS_ms_Avg, TLWin_Avg, TLWout_Avg, VWC_7_Avg, T_7_Avg, VWC_6_Avg, T_6_Avg, RECORD]
# Index: []
#
# [0 rows x 42 columns]
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 37993    False
# 37994    False
# 37995    False
# 37996    False
# 37997    False
# Length: 95752, dtype: bool

# %% [markdown]
# Data for growing season3

# %%
import pandas as pd
import matplotlib.pyplot as plt
# import missingno as msno
import datetime as dt
import numpy as np

#Appending data for corn
corn_1=pd.read_csv('corn_split needed_growing season 3',parse_dates=['Time','Time11'],na_values=['NAN'])
corn_2=pd.read_csv('corn_10min_dec_apr22.csv',parse_dates=['Time','Time11'],na_values=['NAN'])
# cotton_3=pd.read_csv('cotton_21_raw_10min_may28.csv',parse_dates=['Time'],na_values=['NAN'])
# cotton_4=pd.read_csv('cotton 10 min raw june july 2021.csv',parse_dates=['Time'],na_values=['NAN'])
# #cotton_1=pd.read_csv('Cotton_10_min_Season_1_and_2_raw.csv',parse_dates=['Time'],na_values=['NAN'])
# cotton_5=pd.read_csv('cotton 10 min raw july 13_20_2021.csv',parse_dates=['Time'],na_values=['NAN'])
# cotton_6=pd.read_csv('cotton 10 min raw july 20_25_2021.csv',parse_dates=['Time'],na_values=['NAN'])
# cotton_7=pd.read_csv('Cotton 10 minutes raw july 21to oct  13 2021.csv',parse_dates=['Time'],na_values=['NAN'])
# cotton_8=pd.read_csv('cotton 10 min oct 10 to nov 17_2021_raw.csv',parse_dates=['Time'],na_values=['NAN'])

# cotton_1=pd.read_csv(r'C:\Users\fatemapiu\Desktop\Gardencity\Cotton\daily\unsat\dry_mep_1141_z_5_june2021_unsat.csv',parse_dates=['Time'],na_values=['NAN'])
# cotton_2=pd.read_csv(r'C:\Users\fatemapiu\Desktop\Gardencity\Cotton\daily\unsat\dry_mep_1141_z_5_july2021_unsat.csv',parse_dates=['Time'],na_values=['NAN'])
# cotton_3=pd.read_csv(r'C:\Users\fatemapiu\Desktop\Gardencity\Cotton\daily\unsat\dry_mep_1141_z_5_august2021_unsat.csv',parse_dates=['Time'],na_values=['NAN'])
# cotton_4=pd.read_csv(r'C:\Users\fatemapiu\Desktop\Gardencity\Cotton\daily\unsat\dry_mep_1141_z_5_september2021_unsat.csv',parse_dates=['Time'],na_values=['NAN'])
# cotton_5=pd.read_csv(r'C:\Users\fatemapiu\Desktop\Gardencity\Cotton\daily\unsat\dry_mep_1141_z_5_october2021_unsat.csv',parse_dates=['Time'],na_values=['NAN'])
# cotton_6=pd.read_csv(r'C:\Users\fatemapiu\Desktop\Gardencity\Cotton\daily\unsat\dry_mep_1141_z_5_november2021_unsat.csv',parse_dates=['Time'],na_values=['NAN'])
# cotton_1=pd.read_csv(r'C:\Users\fatemapiu\Desktop\Gardencity\Corn\unsat\corn_mep_1141_z_5_may2021_unsat.csv',parse_dates=['Time'],na_values=['NAN'])
# cotton_2=pd.read_csv(r'C:\Users\fatemapiu\Desktop\Gardencity\Corn\unsat\corn_mep_1141_z_5_june2021_unsat.csv',parse_dates=['Time'],na_values=['NAN'])
# cotton_3=pd.read_csv(r'C:\Users\fatemapiu\Desktop\Gardencity\Corn\unsat\corn_mep_1141_z_5_july2021_unsat.csv',parse_dates=['Time'],na_values=['NAN'])
# cotton_4=pd.read_csv(r'C:\Users\fatemapiu\Desktop\Gardencity\Corn\unsat\corn_mep_1141_z_5_august2021_unsat.csv',parse_dates=['Time'],na_values=['NAN'])
# cotton_5=pd.read_csv(r'C:\Users\fatemapiu\Desktop\Gardencity\Corn\unsat\corn_mep_1141_z_5_september2021_unsat.csv',parse_dates=['Time'],na_values=['NAN'])
# cotton_6=pd.read_csv(r'C:\Users\fatemapiu\Desktop\Gardencity\Corn\unsat\corn_mep_1141_z_5_october2021_unsat.csv',parse_dates=['Time'],na_values=['NAN'])



# cotton_4=pd.read_csv(r'C:\Users\fatemapiu\Desktop\Gardencity\Cotton\daily\unsat\Cotton_mep_1141_z_5_august2021_unsat.csv',parse_dates=['Time'],na_values=['NAN'])
# cotton_5=pd.read_csv(r'C:\Users\fatemapiu\Desktop\Gardencity\Cotton\daily\unsat\Cotton_mep_1141_z_5_semptember2021_unsat.csv',parse_dates=['Time'],na_values=['NAN'])
# cotton_6=pd.read_csv(r'C:\Users\fatemapiu\Desktop\Gardencity\Cotton\daily\unsat\Cotton_mep_1141_z_5_october2021_unsat.csv',parse_dates=['Time'],na_values=['NAN'])
# cotton_7=pd.read_csv(r'C:\Users\fatemapiu\Desktop\Gardencity\Cotton\daily\unsat\Cotton_mep_1141_z_5_november2021_unsat.csv',parse_dates=['Time'],na_values=['NAN'])
# cotton_1=pd.read_csv('East Dry 10 min.csv',parse_dates=['Time'],na_values=['NAN'])
# cotton_2=pd.read_csv('east_dry_10min_july to december2021.csv',parse_dates=['Time'],na_values=['NAN'])
# cotton_1=pd.read_csv('Cotton daily_mean_season1.csv',parse_dates=['Time'],na_values=['NAN'])
# cotton_2=pd.read_csv('Cotton daily_mean_season2.csv',parse_dates=['Time'],na_values=['NAN'])



# cotton_data1=cotton_1.append(cotton_2,ignore_index=False,sort=False)
# cotton_data2=cotton_data1.append(cotton_3,ignore_index=False,sort=False)
# cotton_data3=cotton_data2.append(cotton_4,ignore_index=False,sort=False)
# cotton_data4=cotton_data3.append(cotton_5,ignore_index=False,sort=False)
# cotton_data=cotton_data4.append(cotton_6,ignore_index=False,sort=False)
# cotton_data=cotton_data5.append(cotton_7,ignore_index=False,sort=False)
# cotton_data=cotton_data6.append(cotton_8,ignore_index=False,sort=False)
corn_data=corn_1.append(corn_2,ignore_index=False,sort=False)
# cotton_data2=cotton_data1.append(cotton_3,ignore_index=False,sort=False)

corn_data['Time'] = pd.to_datetime(corn_data['Time'])
print(corn_data['Time'].dtypes)

column_names=['Time']
#duplicates=cotton_data.duplicated(subset=column_names,keep=False)

corn_data.sort_values('Time', inplace = True)
#dropping duplicate values
corn_data.drop_duplicates(subset=column_names,keep='first',inplace=True)

duplicates=corn_data.duplicated(subset=column_names,keep=False)
print(corn_data[duplicates])
print(duplicates)
#saving new file for corn
# cotton_data.to_csv(r'C:\Users\fatemapiu\Desktop\Gardencity\Cotton\daily\unsat\dry_mep_1141_z_5_growing season2021_unsat.csv',na_rep='NAN')
# cotton_data.to_csv(r'C:\Users\fatemapiu\Desktop\Gardencity\Corn\unsat\corn_mep_1141_z_5_growing season2021_unsat.csv',na_rep='NAN')
# cotton_data.to_csv('Cotton daily_1_2_with_adj.csv',na_rep='NAN')
# cotton_data.to_csv('Cotton_10_min_Season_1_and_2_raw.csv',na_rep='NAN')
corn_data.to_csv('Corn 10 min season 1 and 2_raw.csv', na_rep='NAN')

# %%
pip install missingno
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # Data plotting

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import matplotlib

corn=pd.read_csv('Corn 10 min season 1 and 2_raw.csv',parse_dates=['Time'],low_memory=False)
mask=(corn['Time'] >= '11/17/2021  12:00:00 AM') & (corn['Time11'] <= '4/20/2022  11:00:00 PM')
corn=corn.loc[mask]
corn['SHF_1_Avg']=corn['SHF_1_Avg'].astype(float)
corn['SHF_2_Avg']=corn['SHF_2_Avg'].astype(float)
corn['SHF_3_Avg']=corn['SHF_3_Avg'].astype(float)
plt.plot(corn['Time'], corn['SHF_1_Avg'],label='SHF1')
plt.plot(corn['Time'], corn['SHF_2_Avg'],label='SHF2')
plt.plot(corn['Time'], corn['SHF_3_Avg'],label='SHF3')
plt.legend()
plt.show()

# %% [markdown]
# # Data cleaning

# %%
import missingno as msno
import datetime as dt
import numpy as np
#importing Gardencity Corn csv
# corn_data=pd.read_csv('Cotton_10_min_growing_season_2021_22.csv', parse_dates=['Time'],low_memory=False)

#checking data types for time
print(corn_data['Time'].dtypes)

#finding duplicates dates
column_names=['Time']
duplicates=corn_data.duplicated(subset=column_names,keep=False)

#dropping duplicate values
corn_data.drop_duplicates(inplace=True)

#checking if duplicate value is removed
duplicates=corn_data.duplicated(subset=column_names,keep=False)
print(corn_data[duplicates])

#Creating limits for outliner variables

#Battery voltage maximum value 20 minimum value 8
corn_data['BattV_Min']=corn_data['BattV_Min'].astype('float')
corn_data.loc[corn_data['BattV_Min']>20,['BattV_Min']]=np.NAN
corn_data.loc[corn_data['BattV_Min']<8,['BattV_Min']]=np.NAN
 #checking if limit is applied or not
assert corn_data ['BattV_Min'].max()<=20
assert corn_data ['BattV_Min'].min()>=8

#Logger temperature maximum value 50 minimum value -30);
corn_data.loc[corn_data['PTemp_C_Avg']>50,['PTemp_C_Avg']]=np.NAN
corn_data.loc[corn_data['PTemp_C_Avg']<-30,['PTemp_C_Avg']]=np.NAN
 #checking if limit is applied or not
assert corn_data ['PTemp_C_Avg'].max()<=50
assert corn_data ['PTemp_C_Avg'].min()>=-30

#Shortwave radiation In/Out/Net
#Shortwave radiation incoming maximum value 2000 minimum value 0
corn_data['SWin_Avg']=corn_data['SWin_Avg'].astype('float')
corn_data.loc[corn_data['SWin_Avg']>2000,['SWin_Avg']]=np.NAN
corn_data.loc[corn_data['SWin_Avg']<0,['SWin_Avg']]=np.NAN
 #checking if limit is applied or not
assert corn_data ['SWin_Avg'].max()<=2000
assert corn_data ['SWin_Avg'].min()>=0

#Shortwave radiation outgoing maximum value 2000 minimum value -1000
corn_data['SWout_Avg']=corn_data['SWout_Avg'].astype('float')
corn_data.loc[corn_data['SWout_Avg']>2000,['SWout_Avg']]=np.NAN
corn_data.loc[corn_data['SWout_Avg']<-1000,['SWout_Avg']]=np.NAN
 #checking if limit is applied or not
assert corn_data ['SWout_Avg'].max()<=2000
assert corn_data ['SWout_Avg'].min()>=-1000

#Shortwave radiation net maximum value 2000 minimum value -1000
corn_data['SWnet_Avg']=corn_data['SWnet_Avg'].astype('float')
corn_data.loc[corn_data['SWnet_Avg']>2000,['SWnet_Avg']]=np.NAN
corn_data.loc[corn_data['SWnet_Avg']<-1000,['SWnet_Avg']]=np.NAN
 #checking if limit is applied or not
assert corn_data ['SWnet_Avg'].max()<=2000
assert corn_data ['SWnet_Avg'].min()>=-1000

#Longtwave radiation In/Out/Net
#Longwave radiation incoming maximum value 2000 minimum value -1000
corn_data['LWin_Avg']=corn_data['LWin_Avg'].astype('float')
corn_data.loc[corn_data['LWin_Avg']>2000,['LWin_Avg']]=np.NAN
corn_data.loc[corn_data['LWin_Avg']<0,['LWin_Avg']]=np.NAN
 #checking if limit is applied or not
assert corn_data ['LWin_Avg'].max()<=2000
assert corn_data ['LWin_Avg'].min()>=0

#Longwave radiation outgoing maximum value 2000 minimum value -1000
corn_data['LWout_Avg']=corn_data['LWout_Avg'].astype('float')
corn_data.loc[corn_data['LWout_Avg']>2000,['LWout_Avg']]=np.NAN
corn_data.loc[corn_data['LWout_Avg']<-1000,['LWout_Avg']]=np.NAN
 #checking if limit is applied or not
assert corn_data ['LWout_Avg'].max()<=2000
assert corn_data ['LWout_Avg'].min()>=-1000

#Longwave radiation net maximum value 2000 minimum value -1000
corn_data['LWnet_Avg']=corn_data['LWnet_Avg'].astype('float')
corn_data.loc[corn_data['LWnet_Avg']>2000,['LWnet_Avg']]=np.NAN
corn_data.loc[corn_data['LWnet_Avg']<-1000,['LWnet_Avg']]=np.NAN
 #checking if limit is applied or not
assert corn_data ['LWnet_Avg'].max()<=2000
assert corn_data ['LWnet_Avg'].min()>=-1000

#Net radiation maximum value 2000 minimum value -1000
corn_data['NR_Avg']=corn_data['NR_Avg'].astype('float')
corn_data.loc[corn_data['NR_Avg']>2000,['NR_Avg']]=np.NAN
corn_data.loc[corn_data['NR_Avg']<-1000,['NR_Avg']]=np.NAN
 #checking if limit is applied or not
assert corn_data ['NR_Avg'].max()<=2000
assert corn_data ['NR_Avg'].min()>=-1000

#Albedo

#Air temperature maximum value 50 minimum value -30
   #Air temperature at 180cm
corn_data['AirTC_Avg']=corn_data['AirTC_Avg'].astype('float')
corn_data.loc[corn_data['AirTC_Avg']>50,['AirTC_Avg']]=np.NAN
corn_data.loc[corn_data['AirTC_Avg']<-30,['AirTC_Avg']]=np.NAN
 #checking if limit is applied or not
assert corn_data ['AirTC_Avg'].max()<=50
assert corn_data ['AirTC_Avg'].min()>=-30

   #Air temperature at 20cm
corn_data['AirTC_2_Avg']=corn_data['AirTC_2_Avg'].astype('float')
corn_data.loc[corn_data['AirTC_2_Avg']>50,['AirTC_2_Avg']]=np.NAN
corn_data.loc[corn_data['AirTC_2_Avg']<-30,['AirTC_2_Avg']]=np.NAN
 #checking if limit is applied or not
assert corn_data ['AirTC_2_Avg'].max()<=50
assert corn_data ['AirTC_2_Avg'].min()>=-30

#Air humidity maximum value 100 minimum value 0
   #Air humidity at 180 cm
corn_data['RH_Max']=corn_data['RH_Max'].astype('float')
corn_data.loc[corn_data['RH_Max']>100,['RH_Max']]=np.NAN
corn_data.loc[corn_data['RH_Max']<0,['RH_Max']]=np.NAN
 #checking if limit is applied or not
assert corn_data ['RH_Max'].max()<=100
assert corn_data ['RH_Max'].min()>=0

   #Air humidity at 20 cm
corn_data['RH_2_Max']=corn_data['RH_2_Max'].astype('float')
corn_data.loc[corn_data['RH_2_Max']>100,['RH_2_Max']]=np.NAN
corn_data.loc[corn_data['RH_2_Max']<0,['RH_2_Max']]=np.NAN
 #checking if limit is applied or not
assert corn_data ['RH_2_Max'].max()<=100
assert corn_data ['RH_2_Max'].min()>=0

#Surface temperature maximum value 60 minimum value -30
corn_data['TT_C_Avg']=corn_data['TT_C_Avg'].astype('float')
corn_data.loc[corn_data['TT_C_Avg']>60,['TT_C_Avg']]=np.NAN
corn_data.loc[corn_data['TT_C_Avg']<-30,['TT_C_Avg']]=np.NAN
 #checking if limit is applied or not
assert corn_data ['TT_C_Avg'].max()<=60
assert corn_data ['TT_C_Avg'].min()>=-30

#Subsurface temperature maximum value 60 minimum value -30
corn_data['T109_C_Avg']=corn_data['T109_C_Avg'].astype('float')
corn_data.loc[corn_data['T109_C_Avg']>60,['T109_C_Avg']]=np.NAN
corn_data.loc[corn_data['T109_C_Avg']<-30,['T109_C_Avg']]=np.NAN
 #checking if limit is applied or not
assert corn_data ['T109_C_Avg'].max()<=60
assert corn_data ['T109_C_Avg'].min()>=-30

#Windspeed maximum value 100 minimum value 0
#cotton_data=pd.read_csv('Cotton_10_min_june_feb.csv',parse_dates=[0],low_memory=False)
corn_data['WS_ms_Avg']=corn_data['WS_ms_Avg'].astype('float')
corn_data.loc[corn_data['WS_ms_Avg']>100,['WS_ms_Avg']]=np.NAN
corn_data.loc[corn_data['WS_ms_Avg']<0,['WS_ms_Avg']]=np.NAN
#checking if limit is applied or not
assert corn_data['WS_ms_Avg'].max()<=100
assert corn_data['WS_ms_Avg'].min()>=0

#Rainfall maximum value 200 minimum value 0
corn_data.loc[corn_data['Rain_mm_Tot']>200,['Rain_mm_Tot']]=np.NAN
corn_data.loc[corn_data['Rain_mm_Tot']<0,['Rain_mm_Tot']]=np.NAN
 #checking if limit is applied or not
assert corn_data ['Rain_mm_Tot'].max()<=200
assert corn_data ['Rain_mm_Tot'].min()>=0

#Surface heat flux maximum value 50 minimum value -50
   #Surface heat flux 1
corn_data['SHF_1_Avg']=corn_data['SHF_1_Avg'].astype('float')
corn_data.loc[corn_data['SHF_1_Avg']>50,['SHF_1_Avg']]=np.NAN
corn_data.loc[corn_data['SHF_1_Avg']<-50,['SHF_1_Avg']]=np.NAN
 #checking if limit is applied or not
assert corn_data ['SHF_1_Avg'].max()<=50
assert corn_data ['SHF_1_Avg'].min()>=-50

   #Surface heat flux 2
corn_data['SHF_2_Avg']=corn_data['SHF_2_Avg'].astype(float)
corn_data.loc[corn_data['SHF_2_Avg']>50,['SHF_2_Avg']]=np.NAN
corn_data.loc[corn_data['SHF_2_Avg']<-50,['SHF_2_Avg']]=np.NAN
 #checking if limit is applied or not
assert corn_data ['SHF_2_Avg'].max()<=50
assert corn_data ['SHF_2_Avg'].min()>=-50

   #Surface heat flux 3
corn_data['SHF_3_Avg']=corn_data['SHF_3_Avg'].astype('float')
corn_data.loc[corn_data['SHF_3_Avg']>50,['SHF_3_Avg']]=np.NAN
corn_data.loc[corn_data['SHF_3_Avg']<-50,['SHF_3_Avg']]=np.NAN
 #checking if limit is applied or not
assert corn_data ['SHF_3_Avg'].max()<=50
assert corn_data ['SHF_3_Avg'].min()>=-50

#Soil Water Content maximum value 100 minimum value 0

  #Water content at 5cm
corn_data['VWC_1_Avg']=corn_data['VWC_1_Avg'].astype(float)
corn_data.loc[corn_data['VWC_1_Avg']>100,['VWC_1_Avg']]=np.NAN
corn_data.loc[corn_data['VWC_1_Avg']<0,['VWC_1_Avg']]=np.NAN
 #checking if limit is applied or not
assert corn_data ['VWC_1_Avg'].max()<=100
assert corn_data ['VWC_1_Avg'].min()>=0

  #Water content at 10cm
corn_data['VWC_2_Avg']=corn_data['VWC_2_Avg'].astype(float)
corn_data.loc[corn_data['VWC_2_Avg']>100,['VWC_2_Avg']]=np.NAN
corn_data.loc[corn_data['VWC_2_Avg']<0,['VWC_2_Avg']]=np.NAN
 #checking if limit is applied or not
assert corn_data ['VWC_2_Avg'].max()<=100
assert corn_data ['VWC_2_Avg'].min()>=0

  #Water content at 20cm
corn_data['VWC_3_Avg']=corn_data['VWC_3_Avg'].astype(float)
corn_data.loc[corn_data['VWC_3_Avg']>100,['VWC_3_Avg']]=np.NAN
corn_data.loc[corn_data['VWC_3_Avg']<0,['VWC_3_Avg']]=np.NAN
 #checking if limit is applied or not
assert corn_data ['VWC_3_Avg'].max()<=100
assert corn_data ['VWC_3_Avg'].min()>=0

  #Water content at 40cm
corn_data['VWC_4_Avg']=corn_data['VWC_4_Avg'].astype(float)
corn_data.loc[corn_data['VWC_4_Avg']>100,['VWC_4_Avg']]=np.NAN
corn_data.loc[corn_data['VWC_4_Avg']<0,['VWC_4_Avg']]=np.NAN
 #checking if limit is applied or not
assert corn_data ['VWC_4_Avg'].max()<=100
assert corn_data ['VWC_4_Avg'].min()>=0

  #Water content at 60cm
corn_data['VWC_5_Avg']=corn_data['VWC_5_Avg'].astype(float)
corn_data.loc[corn_data['VWC_5_Avg']>100,['VWC_5_Avg']]=np.NAN
corn_data.loc[corn_data['VWC_5_Avg']<0,['VWC_5_Avg']]=np.NAN
 #checking if limit is applied or not
assert corn_data ['VWC_5_Avg'].max()<=100
assert corn_data ['VWC_5_Avg'].min()>=0

#Soil temperature maximum value 60 minimum value -30

  #Temperature at 5cm
corn_data['T_1_Avg']=corn_data['T_1_Avg'].astype(float)
corn_data.loc[corn_data['T_1_Avg']>60,['T_1_Avg']]=np.NAN
corn_data.loc[corn_data['T_1_Avg']<-30,['T_1_Avg']]=np.NAN
 #checking if limit is applied or not
assert corn_data ['T_1_Avg'].max()<=60
assert corn_data ['T_1_Avg'].min()>=-30

  # Temperature at 10cm
corn_data['T_2_Avg']=corn_data['T_2_Avg'].astype(float)
corn_data.loc[corn_data['T_2_Avg'] > 60, ['T_2_Avg']] = np.NAN
corn_data.loc[corn_data['T_2_Avg'] < -30, ['T_2_Avg']] = np.NAN
# checking if limit is applied or not
assert corn_data['T_2_Avg'].max() <= 60
assert corn_data['T_2_Avg'].min() >= -30

  # Temperature at 20cm
corn_data['T_3_Avg']=corn_data['T_3_Avg'].astype(float)
corn_data.loc[corn_data['T_3_Avg'] > 60, ['T_3_Avg']] = np.NAN
corn_data.loc[corn_data['T_3_Avg'] < -30, ['T_3_Avg']] = np.NAN
# checking if limit is applied or not
assert corn_data['T_3_Avg'].max() <= 60
assert corn_data['T_3_Avg'].min() >= -30

  # Temperature at 40cm
corn_data['T_4_Avg']=corn_data['T_4_Avg'].astype(float)
corn_data.loc[corn_data['T_4_Avg'] > 60, ['T_4_Avg']] = np.NAN
corn_data.loc[corn_data['T_4_Avg'] < -30, ['T_4_Avg']] = np.NAN
# checking if limit is applied or not
assert corn_data['T_4_Avg'].max() <= 60
assert corn_data['T_4_Avg'].min() >= -30

  # Temperature at 60cm
corn_data['T_5_Avg']=corn_data['T_5_Avg'].astype(float)
corn_data.loc[corn_data['T_5_Avg'] > 60, ['T_5_Avg']] = np.NAN
corn_data.loc[corn_data['T_5_Avg'] < -30, ['T_5_Avg']] = np.NAN
# checking if limit is applied or not
assert corn_data['T_5_Avg'].max() <= 60
assert corn_data['T_5_Avg'].min() >= -30

#Saving clean data
corn_data.to_csv("Cotton Clean 10 min Growing Season 2021_22.csv",na_rep='NAN')

# %% [markdown]
# # Data aggregation

# %%
import pandas as pd
import numpy as np
#importing csv file for corn
# corn_data=pd.read_csv('Cotton 10 min season 1 and 2_raw.csv',parse_dates=['Time','Time11'],index_col=['Time'],na_values=['NAN'])
corn_data=pd.read_csv(r'C:\Users\fatem\OneDrive - Virginia Tech\Desktop\readings\Gardencity\Cotton 10 min season 1 to 3_raw.csv',parse_dates=['Time','Time11'],index_col=['Time'],na_values=['NAN'])

# corn_data=pd.read_csv('Corn 10 min Growing Season 2021_22.csv',parse_dates=['Time'],index_col=['Time'],na_values=['NAN'])
#setting threshold for soil heat flux
# corn_data.loc[corn_data['SHF_1_Avg']>200,['SHF_1_Avg']]=np.NAN
# corn_data.loc[corn_data['SHF_1_Avg']<-200,['SHF_1_Avg']]=np.NAN
#  #checking if limit is applied or not
# assert corn_data ['SHF_1_Avg'].max()<=200
# assert corn_data['SHF_1_Avg'].min()>=-200

#    #Surface heat flux 2
# corn_data.loc[corn_data['SHF_2_Avg']>200,['SHF_2_Avg']]=np.NAN
# corn_data.loc[corn_data['SHF_2_Avg']<-200,['SHF_2_Avg']]=np.NAN
#  #checking if limit is applied or not
# assert corn_data ['SHF_2_Avg'].max()<=200
# assert corn_data ['SHF_2_Avg'].min()>=-200

#    #Surface heat flux 3
# corn_data['SHF_3_Avg']=corn_data['SHF_3_Avg'].astype('float')
# corn_data.loc[corn_data['SHF_3_Avg']>200,['SHF_3_Avg']]=np.NAN
# corn_data.loc[corn_data['SHF_3_Avg']<-200,['SHF_3_Avg']]=np.NAN
#  #checking if limit is applied or not
# assert corn_data ['SHF_3_Avg'].max()<=200
# assert corn_data['SHF_3_Avg'].min()>=-200

# p=1334.18
# corn_data['SHF']=corn_data[['SHF_1_Avg','SHF_2_Avg','SHF_3_Avg']].median(axis=1)
# porosity=1-(p/2650) #corn['VWC_1_Avg']
# corn_data['porosity']=porosity
# Cs_unsat=((1331*776)+(4182*1000*corn_data['VWC_1_Avg']))
# Cs_sat=((1331*776)+(4182*1000*corn_data['porosity']))
# corn_data['prev_T'] = [np.nan] + corn_data.iloc[:-1]['T_1_Avg'].tolist()
# corn_data['Ts']=corn_data['T_1_Avg']-corn_data['prev_T']
# # print(corn_data['Ts'])
# s_unsat=((corn_data['Ts'])*Cs_unsat*0.05)/(10*60)
# s_sat=((corn_data['Ts'])*Cs_sat*0.05)/(10*60)
# corn_data['Gs_unsat']=(corn_data['SHF']+s_unsat)
# corn_data['Gs_sat']=(corn_data['SHF']+s_sat)

# corn_data=pd.read_csv(r'C:\Users\fatemapiu\Desktop\Gardencity\Corn\unsat\corn 60 mean 1141_z5_2021unsat.csv',parse_dates=['Time'],index_col=['Time'],na_values=['NAN'])
# corn_data=pd.read_csv(r'C:\Users\fatemapiu\Desktop\Gardencity\Corn\unsat\dry 60 mean 1141_z5_2021unsat.csv',parse_dates=['Time'],index_col=['Time'],na_values=['NAN'])
#masking as swin correction factor differs for each season
# mask=(corn_data['Time11'] >= '6/17/2020  12:00:00 AM') & (corn_data['Time11'] <= '5/17/2021  11:00:00 PM')
# corn_data_s1=corn_data.loc[mask]
# mask1=(corn_data['Time11'] >= '5/18/2021  12:00:00 AM') & (corn_data['Time11'] <= '4/21/2022  11:00:00 PM')
# corn_data_s2=corn_data.loc[mask1]

#corn_data=pd.read_csv('Corn_10_min_june_may27.csv',parse_dates=['Time'],index_col=['Time'],na_values=['NAN'])
#corn=Corn_10_min_growing_season_june_to_20oct.csv,Cotton 10min Clean data June to Dec_growing season.csv
#cotton=pd.read_csv('Cotton daily_mean.csv',parse_dates=['Time'],index_col=['Time'],na_values=['NAN'])
#mask=(cotton['Time'] > '6/15/2020') & (cotton['Time'] <= '10/20/2021')
#Corn Clean 10 min Growing Season 2021_22_adj.csv
#print(corn_data['SWin_adj'])
# corn_data['SWin_adj'] = corn_data['SWin_adj'].replace('','')
#for 2020 Swin 0.9128 and swout 1.19638
# corn_data_s1['SWin_adj']=corn_data_s1['SWin_Avg']*0.9128 #0.91203 for cotton
# corn_data_s1['SWout_adj']=corn_data_s1['SWout_Avg']*1.19638
# corn_data_s1['LWin_adj']=corn_data_s1['LWin_Avg']+3*10**-9*(corn_data_s1['AirTC_Avg']+273)**4
# corn_data_s1['NR_adj']=corn_data_s1['SWin_adj']-corn_data_s1['SWout_adj']+corn_data_s1['LWin_adj']-corn_data_s1['LWout_Avg']

#for 2021 SWin 0.9120 SWout 1.19638
# corn_data_s2['SWin_adj']=corn_data_s2['SWin_Avg']*0.9120 #0.91203 for cotton
# corn_data_s2['SWout_adj']=corn_data_s2['SWout_Avg']*1.19638
# corn_data_s2['LWin_adj']=corn_data_s2['LWin_Avg']+3*10**-9*(corn_data_s2['AirTC_Avg']+273)**4
# corn_data_s2['NR_adj']=corn_data_s2['SWin_adj']-corn_data_s2['SWout_adj']+corn_data_s2['LWin_adj']-corn_data_s2['LWout_Avg']


# cotton=pd.read_csv('Cotton_10_min_june_april_clean.csv',parse_dates=['Time'],index_col=['Time'],na_values=['NAN'])
#cotton=pd.read_csv('Cotton 60min_mean.csv',parse_dates=[0],index_col=[0],na_values=['NAN'])
#60 minutes interval data for corn using mean
#data1=pd.read_csv('swrec_data.csv',parse_dates=[0],index_col=[0],na_values=['NAN'])
#corn_data['Wind']=cotton['WS_ms_Avg']
#corn_data['Net Radiation']=cotton['NR_Avg']
#corn_data.to_csv('Corn Clean 10 min Growing Season 2021_22_adj.csv',na_rep='NAN')
#research_data.index = pd.to_datetime(research_data.index.astype(str))
#data=data1.resample('60min', label='left').mean()
#data.to_csv('SWREC_hourly.csv',na_rep='NAN')
#data=data1.resample('D', label='left').mean()
#data.to_csv('SWREC_daily.csv',na_rep='NAN')
# corn_daily=corn_data.resample('D', label='left').sum()
# corn_daily=corn_data.resample('D', label='left').mean()
corn=corn_data.resample('60min',label='left').mean()
# corn=corn_data.resample('60min', label='left').max()
# corn=corn_data.resample('60min', label='left').min()
#corn_daily=corn_data.resample('D', label='left').median()
#corn=corn_data.resample('60min',label='left').mean()
# corn_daily=corn_data.resample('D', label='left').mean()
#print(corn_data.index)
# corn_daily_s1=corn_data_s1.resample('D', label='left').mean()
# corn_daily_s2=corn_data_s2.resample('D', label='left').mean()
#corn_60min_mean=pd.read_csv('Corn 60min_mean.csv',parse_dates=[0],index_col=[0],na_values=['NAN'])
# corn_daily.to_csv(r'C:\Users\fatemapiu\Desktop\Gardencity\Corn\unsat\corn daily mean 1141_z5_2021unsat.csv',na_rep='NAN')
# corn_daily.to_csv(r'C:\Users\fatemapiu\Desktop\Gardencity\Cotton\daily\unsat\dry daily mean 1141_z5_2021unsat.csv',na_rep='NAN')

#corn_60min_median=corn_data.resample('60min', label='right').mean()
#corn['WS_ms_Avg']=cotton['WS_ms_Avg']
# corn.to_csv('Corn 60min_mean_season1 and 2_raw.csv',na_rep='NAN')
corn.to_csv(r'C:\Users\fatem\OneDrive - Virginia Tech\Desktop\readings\Gardencity\trial_cotton_hr_whole.csv',na_rep='NAN')
# corn.to_csv('Corn 60min_max.csv',na_rep='NAN')
# corn.to_csv('Corn 60min_min.csv',na_rep='NAN')
# corn_daily.to_csv('Corn daily_sum_growing_season1_and2_raw.csv',na_rep='NAN')
# corn_daily.to_csv('Corn daily_mean_growing_season1_and2_raw.csv',na_rep='NAN')
# corn_daily_s1.to_csv('Corn daily_mean_1_adj.csv',na_rep='NAN')
# corn_daily_s2.to_csv('Corn daily_mean_season2.csv',na_rep='NAN')
# corn_daily.to_csv('Corn daily_mean_growing_season2_adj.csv',na_rep='NAN')
#Cotton daily_mean_growing_season1_adj.csv
#corn_daily.to_csv('Corn daily_min_growing_season1.csv',na_rep='NAN')
#corn_daily.to_csv('Corn daily_median.csv',na_rep='NAN')
#30 minutes interval data for cotton using mean
#corn_30min_mean=corn_data.resample('30min', label='right').mean()

#saving 30 mins interval corn data(mean)
#corn_30min_mean.to_csv('Corn 30min_mean.csv',na_rep='NAN')


#30 minutes interval data for corn using median
#corn_30min_median=corn_data.resample('30min',label='right').median()

#saving 30 mins interval corn data(median)
#corn_30min_median.to_csv('Corn 30min_median.csv',na_rep='NAN')

# %%
import pandas as pd
import numpy as np
#importing csv file for corn
corn_data=pd.read_csv('Cotton 10 min season 1 and 2_raw.csv',parse_dates=['Time','Time11'],index_col=['Time'],na_values=['NAN'])
# corn_data=pd.read_csv('Corn 10 min Growing Season 2021_22.csv',parse_dates=['Time'],index_col=['Time'],na_values=['NAN'])
#setting threshold for soil heat flux
# corn_data.loc[corn_data['SHF_1_Avg']>200,['SHF_1_Avg']]=np.NAN
# corn_data.loc[corn_data['SHF_1_Avg']<-200,['SHF_1_Avg']]=np.NAN
#  #checking if limit is applied or not
# assert corn_data ['SHF_1_Avg'].max()<=200
# assert corn_data['SHF_1_Avg'].min()>=-200

#    #Surface heat flux 2
# corn_data.loc[corn_data['SHF_2_Avg']>200,['SHF_2_Avg']]=np.NAN
# corn_data.loc[corn_data['SHF_2_Avg']<-200,['SHF_2_Avg']]=np.NAN
#  #checking if limit is applied or not
# assert corn_data ['SHF_2_Avg'].max()<=200
# assert corn_data ['SHF_2_Avg'].min()>=-200

#    #Surface heat flux 3
# corn_data['SHF_3_Avg']=corn_data['SHF_3_Avg'].astype('float')
# corn_data.loc[corn_data['SHF_3_Avg']>200,['SHF_3_Avg']]=np.NAN
# corn_data.loc[corn_data['SHF_3_Avg']<-200,['SHF_3_Avg']]=np.NAN
#  #checking if limit is applied or not
# assert corn_data ['SHF_3_Avg'].max()<=200
# assert corn_data['SHF_3_Avg'].min()>=-200

# p=1334.18
# corn_data['SHF']=corn_data[['SHF_1_Avg','SHF_2_Avg','SHF_3_Avg']].median(axis=1)
# porosity=1-(p/2650) #corn['VWC_1_Avg']
# corn_data['porosity']=porosity
# Cs_unsat=((1331*776)+(4182*1000*corn_data['VWC_1_Avg']))
# Cs_sat=((1331*776)+(4182*1000*corn_data['porosity']))
# corn_data['prev_T'] = [np.nan] + corn_data.iloc[:-1]['T_1_Avg'].tolist()
# corn_data['Ts']=corn_data['T_1_Avg']-corn_data['prev_T']
# # print(corn_data['Ts'])
# s_unsat=((corn_data['Ts'])*Cs_unsat*0.05)/(10*60)
# s_sat=((corn_data['Ts'])*Cs_sat*0.05)/(10*60)
# corn_data['Gs_unsat']=(corn_data['SHF']+s_unsat)
# corn_data['Gs_sat']=(corn_data['SHF']+s_sat)

# corn_data=pd.read_csv(r'C:\Users\fatemapiu\Desktop\Gardencity\Corn\unsat\corn 60 mean 1141_z5_2021unsat.csv',parse_dates=['Time'],index_col=['Time'],na_values=['NAN'])
# corn_data=pd.read_csv(r'C:\Users\fatemapiu\Desktop\Gardencity\Corn\unsat\dry 60 mean 1141_z5_2021unsat.csv',parse_dates=['Time'],index_col=['Time'],na_values=['NAN'])
#masking as swin correction factor differs for each season
# mask=(corn_data['Time11'] >= '6/17/2020  12:00:00 AM') & (corn_data['Time11'] <= '5/17/2021  11:00:00 PM')
# corn_data_s1=corn_data.loc[mask]
mask1=(corn_data['Time11'] >= '5/18/2021  12:00:00 AM') & (corn_data['Time11'] <= '4/21/2022  11:00:00 PM')
corn_data_s2=corn_data.loc[mask1]

#corn_data=pd.read_csv('Corn_10_min_june_may27.csv',parse_dates=['Time'],index_col=['Time'],na_values=['NAN'])
#corn=Corn_10_min_growing_season_june_to_20oct.csv,Cotton 10min Clean data June to Dec_growing season.csv
#cotton=pd.read_csv('Cotton daily_mean.csv',parse_dates=['Time'],index_col=['Time'],na_values=['NAN'])
#mask=(cotton['Time'] > '6/15/2020') & (cotton['Time'] <= '10/20/2021')
#Corn Clean 10 min Growing Season 2021_22_adj.csv
#print(corn_data['SWin_adj'])
# corn_data['SWin_adj'] = corn_data['SWin_adj'].replace('','')
#for 2020 Swin 0.9128 and swout 1.19638
# corn_data_s1['SWin_adj']=corn_data_s1['SWin_Avg']*0.9128 #0.91203 for cotton
# corn_data_s1['SWout_adj']=corn_data_s1['SWout_Avg']*1.19638
# corn_data_s1['LWin_adj']=corn_data_s1['LWin_Avg']+3*10**-9*(corn_data_s1['AirTC_Avg']+273)**4
# corn_data_s1['NR_adj']=corn_data_s1['SWin_adj']-corn_data_s1['SWout_adj']+corn_data_s1['LWin_adj']-corn_data_s1['LWout_Avg']

#for 2021 SWin 0.9120 SWout 1.19638
corn_data_s2['SWin_adj']=corn_data_s2['SWin_Avg']*0.9120 #0.91203 for cotton
corn_data_s2['SWout_adj']=corn_data_s2['SWout_Avg']*1.19638
corn_data_s2['LWin_adj']=corn_data_s2['LWin_Avg']+3*10**-9*(corn_data_s2['AirTC_Avg']+273)**4
corn_data_s2['NR_adj']=corn_data_s2['SWin_adj']-corn_data_s2['SWout_adj']+corn_data_s2['LWin_adj']-corn_data_s2['LWout_Avg']


# cotton=pd.read_csv('Cotton_10_min_june_april_clean.csv',parse_dates=['Time'],index_col=['Time'],na_values=['NAN'])
#cotton=pd.read_csv('Cotton 60min_mean.csv',parse_dates=[0],index_col=[0],na_values=['NAN'])
#60 minutes interval data for corn using mean
#data1=pd.read_csv('swrec_data.csv',parse_dates=[0],index_col=[0],na_values=['NAN'])
#corn_data['Wind']=cotton['WS_ms_Avg']
#corn_data['Net Radiation']=cotton['NR_Avg']
#corn_data.to_csv('Corn Clean 10 min Growing Season 2021_22_adj.csv',na_rep='NAN')
#research_data.index = pd.to_datetime(research_data.index.astype(str))
#data=data1.resample('60min', label='left').mean()
#data.to_csv('SWREC_hourly.csv',na_rep='NAN')
#data=data1.resample('D', label='left').mean()
#data.to_csv('SWREC_daily.csv',na_rep='NAN')
# corn_daily=corn_data.resample('D', label='left').sum()
# corn_daily=corn_data.resample('D', label='left').mean()
# corn=corn_data_s2.resample('60min',label='left').mean()
corn=corn_data_s2.resample('60min', label='left').min()
# corn=corn_data.resample('60min', label='left').min()
#corn_daily=corn_data.resample('D', label='left').median()
#corn=corn_data.resample('60min',label='left').mean()
# corn_daily=corn_data.resample('D', label='left').mean()
#print(corn_data.index)
# corn_daily_s1=corn_data_s1.resample('D', label='left').mean()
# corn_daily_s2=corn_data_s2.resample('D', label='left').mean()
#corn_60min_mean=pd.read_csv('Corn 60min_mean.csv',parse_dates=[0],index_col=[0],na_values=['NAN'])
# corn_daily.to_csv(r'C:\Users\fatemapiu\Desktop\Gardencity\Corn\unsat\corn daily mean 1141_z5_2021unsat.csv',na_rep='NAN')
# corn_daily.to_csv(r'C:\Users\fatemapiu\Desktop\Gardencity\Cotton\daily\unsat\dry daily mean 1141_z5_2021unsat.csv',na_rep='NAN')

#corn_60min_median=corn_data.resample('60min', label='right').mean()
#corn['WS_ms_Avg']=cotton['WS_ms_Avg']
# corn.to_csv('Corn 60min_mean_season1 and 2_raw.csv',na_rep='NAN')
corn.to_csv('Cotton 60min_min_season_2.csv',na_rep='NAN')
# corn.to_csv('Corn 60min_max.csv',na_rep='NAN')
# corn.to_csv('Corn 60min_min.csv',na_rep='NAN')
# corn_daily.to_csv('Corn daily_sum_growing_season1_and2_raw.csv',na_rep='NAN')
# corn_daily.to_csv('Corn daily_mean_growing_season1_and2_raw.csv',na_rep='NAN')
# corn_daily_s1.to_csv('Corn daily_mean_1_adj.csv',na_rep='NAN')
# corn_daily_s2.to_csv('Cotton daily_mean_season2.csv',na_rep='NAN')
# corn_daily.to_csv('Corn daily_mean_growing_season2_adj.csv',na_rep='NAN')
#Cotton daily_mean_growing_season1_adj.csv
#corn_daily.to_csv('Corn daily_min_growing_season1.csv',na_rep='NAN')
#corn_daily.to_csv('Corn daily_median.csv',na_rep='NAN')
#30 minutes interval data for cotton using mean
#corn_30min_mean=corn_data.resample('30min', label='right').mean()

#saving 30 mins interval corn data(mean)
#corn_30min_mean.to_csv('Corn 30min_mean.csv',na_rep='NAN')


#30 minutes interval data for corn using median
#corn_30min_median=corn_data.resample('30min',label='right').median()

#saving 30 mins interval corn data(median)
#corn_30min_median.to_csv('Corn 30min_median.csv',na_rep='NAN')
# Out:
# C:\Users\fatem\AppData\Local\Temp/ipykernel_8828/3678448655.py:64: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   corn_data_s2['SWin_adj']=corn_data_s2['SWin_Avg']*0.9120 #0.91203 for cotton
# C:\Users\fatem\AppData\Local\Temp/ipykernel_8828/3678448655.py:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   corn_data_s2['SWout_adj']=corn_data_s2['SWout_Avg']*1.19638
# C:\Users\fatem\AppData\Local\Temp/ipykernel_8828/3678448655.py:66: SettingWithCopyWarning:
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import matplotlib

corn=pd.read_csv('Corn 60min_mean_season_2.csv',parse_dates=['Time'],low_memory=False)
mask=(corn['Time'] >= '11/17/2021  12:00:00 AM') & (corn['Time'] <= '4/20/2022  11:00:00 PM')
corn=corn.loc[mask]
corn['SHF_1_Avg']=corn['SHF_1_Avg'].astype(float)
corn['SHF_2_Avg']=corn['SHF_2_Avg'].astype(float)
corn['SHF_3_Avg']=corn['SHF_3_Avg'].astype(float)
# plt.plot(corn['Time'], corn['SHF_1_Avg'],label='SHF1')
# plt.plot(corn['Time'], corn['SHF_2_Avg'],label='SHF2')
plt.plot(corn['Time'], corn['SHF_3_Avg'],label='SHF3')
plt.xticks(rotation=45)
plt.legend()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import matplotlib

corn=pd.read_csv('Cotton 60min_mean_season_2.csv',parse_dates=['Time'],low_memory=False)
mask=(corn['Time'] >= '11/17/2021  12:00:00 AM') & (corn['Time'] <= '4/20/2022  11:00:00 PM')
corn=corn.loc[mask]
corn['SHF_1_Avg']=corn['SHF_1_Avg'].astype(float)
corn['SHF_2_Avg']=corn['SHF_2_Avg'].astype(float)
corn['SHF_3_Avg']=corn['SHF_3_Avg'].astype(float)
# plt.plot(corn['Time'], corn['SHF_1_Avg'],label='SHF1')
# plt.plot(corn['Time'], corn['SHF_2_Avg'],label='SHF2')
plt.plot(corn['Time'], corn['SHF_3_Avg'],label='SHF3')
plt.xticks(rotation=45)
plt.legend()
plt.show()
